# %%
import pandas as pd
from functools import reduce

# %%
from functools import reduce

def collective_rank(ranks):

    features = reduce(lambda a, b: a.union(b), [rank.index for rank in ranks])

    aligned = [rank['Harmonic Mean'].reindex(features, fill_value = 0) for df in dfs]
    
    combined = pd.concat(aligned, axis=1)
    
    avg = combined.mean(axis=1)
    
    print(all_indices)
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df1 = pd.DataFrame({'A': [1, 2, 3]}, index=['x', 'y', 'z'])
df2 = pd.DataFrame({'A': [4, 5]}, index=['x', 'y'])
df3 = pd.DataFrame({'A': [10]}, index=['z'])

dfs = [df1, df2, df3]

from functools import reduce

# Collect all indices
all_indices = reduce(lambda a, b: a.union(b), [d.index for d in dfs])

# Align and combine
aligned = [df['A'].reindex(all_indices, fill_value=0) for df in dfs]
combined = pd.concat(aligned, axis=1)

avg = combined.mean(axis=1)

print(avg)
